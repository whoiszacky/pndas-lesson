# %%
import pandas as pd

# %%
data = pd.read_csv("../lesson1002/kc_house_data.csv")
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
max_bedrooms = data["bedrooms"].max()
# to the information we call the variable 
max_bedrooms
# Out:
# 33

# %%
mediaValue_bedrooms = data["bedrooms"].median()
# this function give the median value of a dataset 
mediaValue_bedrooms
# Out:
# 3.0

# %%
data.mode(numeric_only=True)
# Out:
#             id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  795000620.0  350000.0       3.0        2.5       1300.0    5000.0     1.0
# 1          NaN  450000.0       NaN        NaN          NaN       NaN     NaN
# 2          NaN       NaN       NaN        NaN          NaN       NaN     NaN
# 3          NaN       NaN       NaN        NaN          NaN       NaN     NaN
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0         0.0   0.0        3.0    7.0      1300.0            0.0    2014.0
# 1         NaN   NaN        NaN    NaN         NaN            NaN       NaN
# 2         NaN   NaN        NaN    NaN         NaN            NaN       NaN
# 3         NaN   NaN        NaN    NaN         NaN            NaN       NaN
#
#    yr_renovated  zipcode      lat    long  sqft_living15  sqft_lot15
# 0           0.0  98103.0  47.5322 -122.29         1540.0      5000.0
# ...

# %%
info =pd.read_csv("../lesson1002/titanic.csv")
info.mode(numeric_only=True)
# Out:
#    pclass  survived  sibsp  parch
# 0       3         0      0      0

# %%
bestsellers = pd.read_csv("../lesson1002/bestsellers.csv")
bestsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
lowestUser_rating = bestsellers["User Rating"].min()
# lets out put lowest the lowest user rating 

lowestUser_rating
# Out:
# 3.3

# %%
heighestUser_rating = bestsellers["User Rating"].max()
# lets out put the highest user rating 

heighestUser_rating
# Out:
# 4.9

# %%
AvarageUser_rating = bestsellers["User Rating"].mean()

# outputting the avarage user rating 

AvarageUser_rating
# Out:
# 4.618363636363637

# %%
# frist getting the firts top row and storing in this variable called top5 rows and then making the avarage of these five rows
top5_rows = bestsellers.head(6)

average_ratingofTop5 = top5_rows["User Rating"].mean()

average_ratingofTop5
# Out:
# 4.6499999999999995

# %%
# THE RATING SCORE APPEARED THE MOST 

count_RatingScore = bestsellers["User Rating"].value_counts()
count_RatingScore
# Out:
# User Rating
# 4.8    127
# 4.7    108
# 4.6    105
# 4.5     60
# 4.9     52
# 4.4     38
# 4.3     25
# 4.0     14
# 4.2      8
# 4.1      6
# 3.9      3
# 3.8      2
# 3.6      1
# 3.3      1
# Name: count, dtype: int64

# %%
bestsellers.describe(include=["0"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 bestsellers.describe(include=["0"])
#
# File c:\Users\TIVIPT23DST\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:11544, in NDFrame.describe(self, percentiles, include, exclude)
#   11302 @final
#   11303 def describe(
#   11304     self,
#    (...)
#   11307     exclude=None,
#   11308 ) -> Self:
#   11309     """
#   11310     Generate descriptive statistics.
#   11311
#    (...)
#   11542     max            NaN      3.0
#   11543     """
# > 11544     return describe_ndframe(
#   11545         obj=self,
#   11546         include=include,
#   11547         exclude=exclude,
#   11548         percentiles=percentiles,
#   11549     ).__finalize__(self, method="describe")
#
# ...
