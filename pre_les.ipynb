# %%
import pandas as pd

# %%
import pandas as pd 
data = {
    "calories": [420, 380, 390],
    "duration": [50, 40, 45],
    "steps": [5000, 6000, 5500],
    "heart_rate": [80, 85, 78],
    "distance": [3.5, 4.2, 3.9],
    "reps": [15, 12, 10],
    "sets": [3, 3, 4],
    "speed": [10.2, 9.8, 10.5],
    "weight": [150, 160, 140],
    "workout_type": ["running", "cycling", "swimming"]
}    

info = pd.DataFrame(data)

info
# Out:
#    calories  duration  steps  heart_rate  distance  reps  sets  speed  weight  \
# 0       420        50   5000          80       3.5    15     3   10.2     150
# 1       380        40   6000          85       4.2    12     3    9.8     160
# 2       390        45   5500          78       3.9    10     4   10.5     140
#
#   workout_type
# 0      running
# 1      cycling
# 2     swimming

# %%
info.to_csv('exercise_info.csv', index=False)

# %%
info["duration"] = info["duration"].astype(str)+ "minutes"

# %%
info
# Out:
#    calories   duration  steps  heart_rate  distance  reps  sets  speed  \
# 0       420  50minutes   5000          80       3.5    15     3   10.2
# 1       380  40minutes   6000          85       4.2    12     3    9.8
# 2       390  45minutes   5500          78       3.9    10     4   10.5
#
#    weight workout_type
# 0     150      running
# 1     160      cycling
# 2     140     swimming
